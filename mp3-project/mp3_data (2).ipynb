# %% [markdown]
# # MP3 Veri Analizi Projesi
#
# ## Veri Toplama Açıklaması
# Bu projede anket aracılığıyla gençlerin sosyal medya alışkanlıkları ile ilgili veri toplanmıştır.
#
# ### Toplanan Veriler:
#  Gençlerin;
# - Kullandığı sosyal medya uygulamaları
# - Sosyal medyada geçirdikleri süre
# - Sosyal medyayı kullanma amaçları
#
# ### Veri Kaynakları:
# - Google Forms

# %%
import pandas as pd

# JSON dosyasını oku
df = pd.read_json('data_mp3.json')

# İlk 5 satırı göster  
df.head()
# Out:
#                              anket_adi  toplam_katilimci  \
# 0  Gençlerde Sosyal Medya ve Odaklanma                53
# 1  Gençlerde Sosyal Medya ve Odaklanma                53
# 2  Gençlerde Sosyal Medya ve Odaklanma                53
# 3  Gençlerde Sosyal Medya ve Odaklanma                53
# 4  Gençlerde Sosyal Medya ve Odaklanma                53
#
#                                              sorular
# 0  {'id': 1, 'soru': 'Bir günde kaç saat sosyal m...
# 1  {'id': 2, 'soru': 'Sosyal Medya'yı en çok hang...
# 2  {'id': 3, 'soru': 'En çok hangi sosyal medya u...
# 3  {'id': 4, 'soru': 'En çok hangi sosyal medya i...
# 4  {'id': 5, 'soru': 'Sosyal Medya kullanımızın h...
